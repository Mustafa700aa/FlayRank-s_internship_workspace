# %% [markdown]
# <a href="https://colab.research.google.com/github/Mustafa700aa/FlayRank-s_internship_workspace/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mustafa700aa/FlayRank-s_internship_workspace/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Lane: Content Refresh Prioritization
# Why: I chose this lane because predicting which decaying pages will benefit most from being updated directly impacts traffic and revenue, making it a highly practical ML application.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Decision: Which pages should the content team update first?
# Who acts: The SEO and Content Marketing teams.
# Cost of a wrong call: Wasting editorial time and budget on pages that won't recover traffic, while ignoring high-potential pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])
percent_declining = (declining_pages / total_pages) * 100


print(f"Total pages analyzed: {total_pages}")
print(f"Pages with declining traffic: {declining_pages}")
print(f"Percentage of pages needing attention: {percent_declining:.1f}%")
# Out:
# Total pages analyzed: 30000
# Pages with declining traffic: 16262
# Percentage of pages needing attention: 54.2%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
#  My work will provide directional, decision-support insights based on measured data to prioritize content updates.
# What I can't claim: I cannot predict Google's exact ranking algorithm, nor can I provide absolute causal proof that an update will guarantee a specific rank.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
